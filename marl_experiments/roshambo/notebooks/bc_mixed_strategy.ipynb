# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np

from marl.utils import tb_utils
# Out:
# 2022-11-22 09:29:47.088879: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcudart.so.11.0'; dlerror: libcudart.so.11.0: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /home/mxsmith/.conda/envs/model38/lib

# %%
path = f"/scratch/wellman_root/wellman1/mxsmith/results/marl/roshambo/bc_ms/wid_0/"
df = tb_utils.events_to_dataframe(path)
# Out:
# WARNING:tensorflow:From /home/mxsmith/.conda/envs/model38/lib/python3.8/site-packages/tensorflow/python/summary/summary_iterator.py:27: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`

# %%
df
# Out:
# name  accuracy/greedy accuracy/greedy/0 accuracy/greedy/1 accuracy/greedy/2  \
# 0          0.36406252        0.98491377        0.02238806               0.0
# 1          0.34296876        0.98623854        0.02173913               0.0
# 2          0.33515626        0.98834497       0.012919896               0.0
# 3            0.328125         0.9928741       0.004854369               0.0
# 4          0.32500002         0.9556075       0.005050505       0.010964912
# ...               ...               ...               ...               ...
# 11724       0.5804688         0.6937355        0.46403712          0.595122
# 11725      0.58671874        0.70616114        0.45939675         0.5971897
# 11726      0.54843754         0.6691542        0.48463356         0.5601966
# 11727      0.58515626         0.6293706         0.5162907         0.6261468
# 11728       0.5734375         0.6768868         0.4506024         0.6004619
#
# ...

# %%
plt.plot(np.stack(df["learner_steps"]), np.stack(df["accuracy/greedy"]))
plt.xlabel("Learner Steps")
plt.ylabel("Accuracy (Greedy)")
# Out:
# Text(0, 0.5, 'Accuracy (Greedy)')

# %%
fig, axes = plt.subplots(ncols=3, sharey=True, figsize=(12, 4))

axes[0].plot(np.stack(df["learner_steps"]), np.stack(df["accuracy/greedy/0"]))
axes[1].plot(np.stack(df["learner_steps"]), np.stack(df["accuracy/greedy/1"]))
axes[2].plot(np.stack(df["learner_steps"]), np.stack(df["accuracy/greedy/2"]))

axes[0].set_title("Rock")
axes[1].set_title("Paper")
axes[2].set_title("Scissors")
# Out:
# Text(0.5, 1.0, 'Scissors')
